# %%
#Task 1
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('images/cameraman.tif')


plt.imshow(img)
plt.show()

# %%
#Task 2

import cv2
import matplotlib.pyplot as plt

img2 = cv2.imread('images/lena_gray.tif') 


plt.imshow(img2)
plt.show()

# %%
#Task 3

# %%
#Task 4
